# %%
import pandas as pd

# %%
# Read the csv from folder 2, it is still useful for this exercise.
# Index col uses airlines.
df = pd.read_csv('../2_FilteringDataFrame/airline-safety.csv', index_col='airline')

# %%
df.head()
# Out:
#                        avail_seat_km_per_week  incidents_85_99  \
# airline
# Aer Lingus                          320906734                2
# Aeroflot*                          1197672318               76
# Aerolineas Argentinas               385803648                6
# Aeromexico*                         596871813                3
# Air Canada                         1865253802                2
#
#                        fatal_accidents_85_99  fatalities_85_99  \
# airline
# Aer Lingus                                 0                 0
# Aeroflot*                                 14               128
# Aerolineas Argentinas                      0                 0
# Aeromexico*                                1                64
# Air Canada                                 0                 0
#
#                        incidents_00_14  fatal_accidents_00_14  \
# airline
# Aer Lingus                           0                      0
# ...

# %%
# Make the dataframe smaller
daf = df[['incidents_00_14', 'fatal_accidents_00_14', 'fatalities_00_14']]

# %%
daf.head()
# Out:
#                        incidents_00_14  fatal_accidents_00_14  \
# airline
# Aer Lingus                           0                      0
# Aeroflot*                            6                      1
# Aerolineas Argentinas                1                      0
# Aeromexico*                          5                      0
# Air Canada                           2                      0
#
#                        fatalities_00_14
# airline
# Aer Lingus                            0
# Aeroflot*                            88
# Aerolineas Argentinas                 0
# Aeromexico*                           0
# Air Canada                            0

# %%
# Setting index on the go
da = pd.read_csv('../2_FilteringDataFrame/airline-safety.csv')
da.set_index('airline').head()
# Out:
#                        avail_seat_km_per_week  incidents_85_99  \
# airline
# Aer Lingus                          320906734                2
# Aeroflot*                          1197672318               76
# Aerolineas Argentinas               385803648                6
# Aeromexico*                         596871813                3
# Air Canada                         1865253802                2
#
#                        fatal_accidents_85_99  fatalities_85_99  \
# airline
# Aer Lingus                                 0                 0
# Aeroflot*                                 14               128
# Aerolineas Argentinas                      0                 0
# Aeromexico*                                1                64
# Air Canada                                 0                 0
#
#                        incidents_00_14  fatal_accidents_00_14  \
# airline
# Aer Lingus                           0                      0
# ...

# %%
dd = pd.read_csv('recent-grads.csv')
# Setting hierarchical index.
dd = dd.set_index(['Major_category', 'Major'])
dd.head()
# Out:
#                                                           Rank  Major_code  \
# Major_category Major
# Engineering    PETROLEUM ENGINEERING                         1        2419
#                MINING AND MINERAL ENGINEERING                2        2416
#                METALLURGICAL ENGINEERING                     3        2415
#                NAVAL ARCHITECTURE AND MARINE ENGINEERING     4        2417
#                CHEMICAL ENGINEERING                          5        2405
#
#                                                             Total      Men  \
# Major_category Major
# Engineering    PETROLEUM ENGINEERING                       2339.0   2057.0
#                MINING AND MINERAL ENGINEERING               756.0    679.0
#                METALLURGICAL ENGINEERING                    856.0    725.0
#                NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0   1123.0
#                CHEMICAL ENGINEERING                       32260.0  21239.0
#
# ...

# %%
# Select top 10 from every major category, how?
dd[dd.Rank <= 10]
# Out:
#                                                              Rank  Major_code  \
# Major_category    Major
# Engineering       PETROLEUM ENGINEERING                         1        2419
#                   MINING AND MINERAL ENGINEERING                2        2416
#                   METALLURGICAL ENGINEERING                     3        2415
#                   NAVAL ARCHITECTURE AND MARINE ENGINEERING     4        2417
#                   CHEMICAL ENGINEERING                          5        2405
#                   NUCLEAR ENGINEERING                           6        2418
# Business          ACTUARIAL SCIENCE                             7        6202
# Physical Sciences ASTRONOMY AND ASTROPHYSICS                    8        5001
# Engineering       MECHANICAL ENGINEERING                        9        2414
#                   ELECTRICAL ENGINEERING                       10        2408
#
#                                                                Total      Men  \
# ...
